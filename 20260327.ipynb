# %%
import numpy as np

print(np.__version__)
# Out:
# 2.4.3

# %%
alist = [1, 2, 3, 4, 5, 6, 7]

print(type(alist))
print(alist)

ar1 = np.array(alist)

print(type(ar1))
print(ar1)
# Out:
# <class 'list'>
# [1, 2, 3, 4, 5, 6, 7]
# <class 'numpy.ndarray'>
# [1 2 3 4 5 6 7]
